# %%
mylist = ["banana","cherry","apple",]
print(mylist)

item = mylist[2]
print(item)#

mylist = ["banan","cherry","apple"]
print(mylist)#

mylist = ["banana","cherry","apple"]
print(mylist)

for x in mylist:
         print(x)#

mylist = ["banana","cherry","apple"]
print(mylist)

if "apple" in mylist:
     print("yes")
else:
      print("no")#

      mylist = ["banana","cherry","apple"]
print(mylist)

print(len(mylist))#

mylist = ["banana","cherry","apple"]
print(mylist)

mylist.append("lemon")
print(mylist)#

mylist = ["banana","cherry","apple"]
print(mylist)

mylist.insert(1,"blueberry")
print(mylist)#

mylist = ["banana","cherry","apple"]
print(mylist)

item = mylist.pop()
print(item)
print(mylist)#

mylist = ["banana","cherry","apple"]
print(mylist)

item = mylist.remove("cherry")
print(mylist)#

mylist = ["banana","cherry","apple"]
print(mylist)

item = mylist.reverse()
print(mylist)#

mylist = [4, 3, 1, -1, -5, 10]
print(mylist)

new_list = sorted(mylist)
print(mylist)
print(new_list)#

mylist = [0] * 5
print(mylist)

mylist2 = ['1','2','3']
new_list = mylist + mylist2
print(new_list)
